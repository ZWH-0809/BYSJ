# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import ticker

programs=['Chart','Lang','Math','Time']
x=['5%','10%','15%','20%','30%','40%','50%','60%','70%','80%','90%','100%',]
#绘制折线图
def draw(prog):
    sns.set_theme(style='whitegrid',font='Times New Roman',font_scale=2)
    plt.figure(figsize=(10, 8))
    values=pd.read_excel('./MergeData/'+prog+'/d.xlsx')
    values.drop(values.columns[0:3],axis=1,inplace=True)
    values.index=x
    ax=sns.lineplot(data=values, palette="tab10", linewidth=2.5,markers=['o','X','v'],markersize=15)
    ax.set_xlabel("Percentage of Code Examined",fontsize=15)
    ax.set_ylabel("Percentage of Faulty Versions where Fault is Located",fontsize=15)
    ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=1))#转换成百分比
    
    plt.savefig('./'+prog+'.jpg', dpi=1000,bbox_inches='tight')

# %%
for prog in programs:
    draw(prog)

# %%
#绘制箱线图
def draw_box(prog):
 pass
